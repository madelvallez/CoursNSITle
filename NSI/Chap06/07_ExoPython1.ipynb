# %% [markdown]
# ## Exercice 1
#
# Compléter le code ci-dessous pour définir
# 1. la fonction sommet
# 2. la fonction depiler

# %% [markdown]
# |fonction  |description|
# |:---------|:------------|
# |`depiler(p:Pile[T]) -> T` | retire et renvoie l'élément au sommet de `p`|
# |`sommet(p:Pile[T]) -> T`|renvoie l'élément au sommet de `p` sans le retirer|

# %%
class Maillon:
    def __init__(self, val, suiv=None):
        self.valeur = val
        self.suivant = suiv

    def __str__(self):
        if self.suivant is None:
            return str(self.valeur)
        return str(self.valeur) + '-' + str(self.suivant)

class Pile:
    def __init__(self):
        self.haut = None

    def est_vide(self):
        return self.haut is None

    def empiler(self, val):
        self.haut = Maillon(val, self.haut)

    def __str__(self):
        return str(self.haut)

    def sommet(self):
        if p.est_vide:
            raise ValueError('La pile est vide')
        return self.haut.valeur

    def depiler(self):
        if p.est_vide:
            raise ValueError('La pile est vide -> on ne peut pas la dépiler')
        val=sommet(self)
        self.haut=self.haut.suivant
        return val
    
def sommet(p):
    if p.haut is None:
        raise ValueError('La pile est vide')
    return p.haut.valeur

def depiler(p):
    if p.haut is None:
        raise ValueError('La pile est vide -> on ne peut pas la dépiler')
    val=sommet(p)
    p.haut=p.haut.suivant
    return val

# %% [markdown]
# ## Tester le code
#
# On pourra tester le programme proposé avec les instructions suivantes

# %%
p = Pile()
p.empiler(5)
p.empiler(10)
p.empiler(20)

assert sommet(p)==20
assert depiler(p) == 20
assert depiler(p) == 10 
assert depiler(p) == 5
assert p.est_vide()
#sommet(p)
#depiler(p)
print("test ok")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-04a34b5b6c4e> in <module>()
#      10 assert p.est_vide()
#      11 #sommet(p)
# ---> 12 depiler(p)
#      13 print("test ok")
#
# <ipython-input-12-4e15ce4002cd> in depiler(p)
#      41 def depiler(p):
#      42     if p.haut is None:
# ---> 43         raise ValueError('La pile est vide -> on ne peut pas la dépiler')
#      44     val=sommet(p)
#      45     p.haut=p.haut.suivant
#
# ValueError: La pile est vide -> on ne peut pas la dépiler
